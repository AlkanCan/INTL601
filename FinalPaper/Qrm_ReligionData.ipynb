# %%
import pandas as pd

# %%
url="https://raw.githubusercontent.com/datasets/world-religion-projections/main/rounded_percentage.csv"

# %%
df=pd.read_csv('by_rounded_percentage_share_csv.csv')

# %%
df
# Out:
#       Year                    Region                Country  Buddhists  \
# 0     2010                     World          All Countries        7.1
# 1     2010             North America          All Countries        1.1
# 2     2010   Latin America-Caribbean          All Countries        1.0
# 3     2010                    Europe          All Countries        1.0
# 4     2010  Middle East-North Africa          All Countries        1.0
# ...    ...                       ...                    ...        ...
# 1200  2050        Sub-Saharan Africa               Zimbabwe        1.0
# 1201  2050        Sub-Saharan Africa            South Sudan        1.0
# 1202  2050   Latin America-Caribbean                Curacao        1.0
# 1203  2050   Latin America-Caribbean           Sint Maarten        1.0
# 1204  2050   Latin America-Caribbean  Caribbean Netherlands        1.0
#
#       Christians  Folk Religions  Hindus  Jews  Muslims  Other Religions  \
# ...

# %%
my_series = df.iloc[:,1:11].max(numeric_only=True, axis =1 )
my_series.name = "maxval"

# Include maxval in df
df['maxval']=my_series

# %%
df
# Out:
#       Year                    Region                Country  Buddhists  \
# 0     2010                     World          All Countries        7.1
# 1     2010             North America          All Countries        1.1
# 2     2010   Latin America-Caribbean          All Countries        1.0
# 3     2010                    Europe          All Countries        1.0
# 4     2010  Middle East-North Africa          All Countries        1.0
# ...    ...                       ...                    ...        ...
# 1200  2050        Sub-Saharan Africa               Zimbabwe        1.0
# 1201  2050        Sub-Saharan Africa            South Sudan        1.0
# 1202  2050   Latin America-Caribbean                Curacao        1.0
# 1203  2050   Latin America-Caribbean           Sint Maarten        1.0
# 1204  2050   Latin America-Caribbean  Caribbean Netherlands        1.0
#
#       Christians  Folk Religions  Hindus  Jews  Muslims  Other Religions  \
# ...

# %%
df['Religion'] = df.loc[:,'Buddhists':'Unaffiliated'].eq(df['maxval'], axis=0).apply(lambda x: ','.join(df.columns[3:11][x==x.max()]),axis=1)
df
# Out:
#       Year                    Region                Country  Buddhists  \
# 0     2010                     World          All Countries        7.1
# 1     2010             North America          All Countries        1.1
# 2     2010   Latin America-Caribbean          All Countries        1.0
# 3     2010                    Europe          All Countries        1.0
# 4     2010  Middle East-North Africa          All Countries        1.0
# ...    ...                       ...                    ...        ...
# 1200  2050        Sub-Saharan Africa               Zimbabwe        1.0
# 1201  2050        Sub-Saharan Africa            South Sudan        1.0
# 1202  2050   Latin America-Caribbean                Curacao        1.0
# 1203  2050   Latin America-Caribbean           Sint Maarten        1.0
# 1204  2050   Latin America-Caribbean  Caribbean Netherlands        1.0
#
#       Christians  Folk Religions  Hindus  Jews  Muslims  Other Religions  \
# ...

# %%
df1=df[df['Year']==2010]

# %%
df1
# Out:
#      Year                    Region                Country  Buddhists  \
# 0    2010                     World          All Countries        7.1
# 1    2010             North America          All Countries        1.1
# 2    2010   Latin America-Caribbean          All Countries        1.0
# 3    2010                    Europe          All Countries        1.0
# 4    2010  Middle East-North Africa          All Countries        1.0
# ..    ...                       ...                    ...        ...
# 236  2010        Sub-Saharan Africa               Zimbabwe        1.0
# 237  2010        Sub-Saharan Africa            South Sudan        1.0
# 238  2010   Latin America-Caribbean                Curacao        1.0
# 239  2010   Latin America-Caribbean           Sint Maarten        1.0
# 240  2010   Latin America-Caribbean  Caribbean Netherlands        1.0
#
#      Christians  Folk Religions  Hindus  Jews  Muslims  Other Religions  \
# ...

# %%
df1.to_csv('religionall.csv')

# %%
df2=df1[['Country','Religion']]

# %%
df2
# Out:
#                    Country    Religion
# 0            All Countries  Christians
# 1            All Countries  Christians
# 2            All Countries  Christians
# 3            All Countries  Christians
# 4            All Countries     Muslims
# ..                     ...         ...
# 236               Zimbabwe  Christians
# 237            South Sudan  Christians
# 238                Curacao  Christians
# 239           Sint Maarten  Christians
# 240  Caribbean Netherlands  Christians
#
# [241 rows x 2 columns]

# %%
df2.to_csv('countryreligion.csv')
