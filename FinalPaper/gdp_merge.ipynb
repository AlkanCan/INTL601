# %%
import pandas as pd
import numpy as np
import wbdata
import datetime

# %%
df=pd.read_excel('gdp.xls')

# %%
df
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  GDP (current US$)
# 1    Africa Eastern and Southern          AFE  GDP (current US$)
# 2                    Afghanistan          AFG  GDP (current US$)
# 3     Africa Western and Central          AFW  GDP (current US$)
# 4                         Angola          AGO  GDP (current US$)
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  GDP (current US$)
# 262                  Yemen, Rep.          YEM  GDP (current US$)
# 263                 South Africa          ZAF  GDP (current US$)
# 264                       Zambia          ZMB  GDP (current US$)
# 265                     Zimbabwe          ZWE  GDP (current US$)
#
#      Indicator Code          1960          1961          1962          1963  \
# 0    NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# ...

# %%
df1=df.drop(columns=['Indicator Name','Indicator Code'])

# %%
df1
# Out:
#                     Country Name Country Code          1960          1961  \
# 0                          Aruba          ABW           NaN           NaN
# 1    Africa Eastern and Southern          AFE  2.129152e+10  2.180944e+10
# 2                    Afghanistan          AFG  5.377778e+08  5.488889e+08
# 3     Africa Western and Central          AFW  1.040414e+10  1.112789e+10
# 4                         Angola          AGO           NaN           NaN
# ..                           ...          ...           ...           ...
# 261                       Kosovo          XKX           NaN           NaN
# 262                  Yemen, Rep.          YEM           NaN           NaN
# 263                 South Africa          ZAF  8.748597e+09  9.225996e+09
# 264                       Zambia          ZMB  7.130000e+08  6.962857e+08
# 265                     Zimbabwe          ZWE  1.052990e+09  1.096647e+09
#
#              1962          1963          1964          1965          1966  \
# ...

# %%
df1=df1.melt(id_vars=["Country Name", "Country Code"], 
        var_name="Year", 
        value_name="GDP")

# %%
df1
# Out:
#                       Country Name Country Code  Year           GDP
# 0                            Aruba          ABW  1960           NaN
# 1      Africa Eastern and Southern          AFE  1960  2.129152e+10
# 2                      Afghanistan          AFG  1960  5.377778e+08
# 3       Africa Western and Central          AFW  1960  1.040414e+10
# 4                           Angola          AGO  1960           NaN
# ...                            ...          ...   ...           ...
# 16487                       Kosovo          XKX  2021  9.412034e+09
# 16488                  Yemen, Rep.          YEM  2021           NaN
# 16489                 South Africa          ZAF  2021  4.190150e+11
# 16490                       Zambia          ZMB  2021  2.214763e+10
# 16491                     Zimbabwe          ZWE  2021  2.837124e+10
#
# [16492 rows x 4 columns]

# %%
df1['Year']=df1['Year'].astype(int)

# %%
df1=df1[df1['Year'].between(1970, 2017)]

# %%
df1
# Out:
#                       Country Name Country Code  Year           GDP
# 2660                         Aruba          ABW  1970           NaN
# 2661   Africa Eastern and Southern          AFE  1970  4.486458e+10
# 2662                   Afghanistan          AFG  1970  1.748887e+09
# 2663    Africa Western and Central          AFW  1970  2.350461e+10
# 2664                        Angola          AGO  1970           NaN
# ...                            ...          ...   ...           ...
# 15423                       Kosovo          XKX  2017  7.180813e+09
# 15424                  Yemen, Rep.          YEM  2017  2.684223e+10
# 15425                 South Africa          ZAF  2017  3.814488e+11
# 15426                       Zambia          ZMB  2017  2.587360e+10
# 15427                     Zimbabwe          ZWE  2017  1.758489e+10
#
# [12768 rows x 4 columns]

# %%
df1.pd.read_csv()
