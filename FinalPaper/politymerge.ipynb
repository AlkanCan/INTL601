# %%
import pandas as pd

# %%
df1=pd.read_excel('gtd2.xlsx', engine='openpyxl')

# %%
df1
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaT
# 1       197000000002   1970       0     0        NaN         0        NaT
# 2       197001000001   1970       1     0        NaN         0        NaT
# 3       197001000002   1970       1     0        NaN         0        NaT
# 4       197001000003   1970       1     0        NaN         0        NaT
# ...              ...    ...     ...   ...        ...       ...        ...
# 170345  201612310040   2016      12    31        NaN         0        NaT
# 170346  201612310042   2016      12    31        NaN         0        NaT
# 170347  201612310043   2016      12    31        NaN         1        NaT
# 170348  201612310044   2016      12    31        NaN         0        NaT
# 170349  201701270001   2016      12    30        NaN         0        NaT
#
#         country                       country_txt  region  ...  \
# ...

# %%
df=df1[['iyear','country_txt']]

# %%
df_incidents=df.groupby(['iyear', 'country_txt']).size().reset_index().rename(columns={0:''})

# %%
df_incidents
# Out:
#       iyear               country_txt
# 0      1970                 Argentina   21
# 1      1970                 Australia    1
# 2      1970                   Belgium    1
# 3      1970                   Bolivia    1
# 4      1970                    Brazil    6
# ...     ...                       ...  ...
# 3643   2016             United States   61
# 3644   2016                   Uruguay    1
# 3645   2016                 Venezuela    6
# 3646   2016  West Bank and Gaza Strip  157
# 3647   2016                     Yemen  521
#
# [3648 rows x 3 columns]

# %%
df_incidents.to_csv('gtd_incidents.csv')

# %%
df1=pd.read_excel('p5v2018.xlsx', engine='openpyxl')

# %%
df1
# Out:
#        p5    cyear  ccode scode      country  year  flag  fragment  democ  \
# 0       0  7001800    700   AFG  Afghanistan  1800     0       NaN      1
# 1       0  7001801    700   AFG  Afghanistan  1801     0       NaN      1
# 2       0  7001802    700   AFG  Afghanistan  1802     0       NaN      1
# 3       0  7001803    700   AFG  Afghanistan  1803     0       NaN      1
# 4       0  7001804    700   AFG  Afghanistan  1804     0       NaN      1
# ...    ..      ...    ...   ...          ...   ...   ...       ...    ...
# 17569   1  5522014    552   ZIM     Zimbabwe  2014     0       0.0      5
# 17570   1  5522015    552   ZIM     Zimbabwe  2015     0       0.0      5
# 17571   1  5522016    552   ZIM     Zimbabwe  2016     0       0.0      5
# 17572   1  5522017    552   ZIM     Zimbabwe  2017     0       0.0      5
# 17573   1  5522018    552   ZIM     Zimbabwe  2018     0       0.0      5
#
#        autoc  ...  interim  bmonth bday  byear  bprec  post  change   d5   sf  \
# ...

# %%
df2=df1[['year','country','polity2']]

# %%
df_incidents.rename(columns = {'iyear':'year','country_txt':'country'}, inplace = True)

# %%
df_incidents
# Out:
#       year                   country
# 0     1970                 Argentina   21
# 1     1970                 Australia    1
# 2     1970                   Belgium    1
# 3     1970                   Bolivia    1
# 4     1970                    Brazil    6
# ...    ...                       ...  ...
# 3643  2016             United States   61
# 3644  2016                   Uruguay    1
# 3645  2016                 Venezuela    6
# 3646  2016  West Bank and Gaza Strip  157
# 3647  2016                     Yemen  521
#
# [3648 rows x 3 columns]

# %%
merged = df_incidents.merge(df2, on=['year', 'country'])

# %%
merged
# Out:
#       year         country       polity2
# 0     1970       Argentina   21     -9.0
# 1     1970       Australia    1     10.0
# 2     1970         Belgium    1     10.0
# 3     1970         Bolivia    1     -5.0
# 4     1970          Brazil    6     -9.0
# ...    ...             ...  ...      ...
# 3231  2016         Ukraine   60      4.0
# 3232  2016  United Kingdom  104      8.0
# 3233  2016         Uruguay    1     10.0
# 3234  2016       Venezuela    6      4.0
# 3235  2016           Yemen  521      0.0
#
# [3236 rows x 4 columns]

# %%
merged.to_csv('incidents_polity.csv')
